# %% [markdown]
# ### Instação das bibliotecas necessarias para execução do pipeline

# %%
import pandas as pd
from datetime import datetime

# %% [markdown]
# ### Extração dos dados
#
# extrair os dados brutos historicos

# %%
# Acesso ao diretorio dos dados raw

#subir para a pasta raiz do projeto
up_dir = "../"

#acessar caminho do diretorio raw
raw_dir ="sucos/raw/"

#nome do arquivo que contem dos dados brutos
file = "coleta_dados_infestacao.csv"

data_path = up_dir+raw_dir+file
print(data_path)
# Out:
# ../sucos/raw/coleta_dados_infestacao.csv

# %%
# Ler dados de inspetores de praga
df = pd.read_csv(data_path, sep=',', quotechar='"')

# %%
# Adicionando coluna de ingestão de dados

df["dh_ingestao"] = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

# %% [markdown]
# # Load data
#
# Etapa realizada para inserir os dados brutos no datalake.
#
# Os dados são carregados brutos, sem qualquer tipo de transformação.

# %%
# Acesso ao datalake

#subir para a pasta raiz do projeto
up_dir = "../"

#acessar caminho do diretorio raw
datalake_dir ="sucoslake/raw/"

#nome do arquivo que contem dos dados brutos
file = "raw_infestacao.parquet"

lake_path = up_dir+datalake_dir+file
print(lake_path)
# Out:
# ../sucoslake/raw/raw_infestacao.parquet

# %%
df.to_parquet(lake_path, engine="pyarrow", compression="snappy")

# %%
df
# Out:
#     ID  SAFRA        Data          Fazenda  Talhao      Localizacao TipoFruta  \
# 0    1   2025  09/01/2025      Fazenda Sol     100  -22.058,-48.181   Laranja
# 1    2   2025  10/01/2025      Fazenda Lua     102  -22.060,-48.185   Laranja
# 2    3   2025  11/01/2025      Fazenda Sol     101  -22.058,-48.181   Laranja
# 3    4   2025  12/01/2025  Fazenda Estrela    -104  -22.062,-48.190   Laranja
# 4    5   2025  13/01/2025      Fazenda Lua     103  -22.060,-48.185   Laranja
# 5    6   2025  14/01/2025      Fazenda Sol     100  -22.058,-48.181   Laranja
# 6    7   2025  15/01/2025  Fazenda Estrela     105  -22.062,-48.190   Laranja
# 7    8   2025  16/01/2025      Fazenda Lua     102  -22.060,-48.185   Laranja
# 8    9   2025  17/01/2025      Fazenda Sol     101  -22.058,-48.181   Laranja
# 9   10   2025  18/01/2025  Fazenda Estrela     104  -22.062,-48.190   Laranja
# 10  11   2025  19/01/2025      Fazenda Lua    -103  -22.060,-48.185   Laranja
# 11  12   2025  20/01/2025      Fazenda Sol     100  -22.058,-48.181   Laranja
# 12  13   2025  21/01/2025  Fazenda Estrela     105  -22.062,-48.190   Laranja
# 13  14   2025  22/01/2025      Fazenda Lua     102  -22.060,-48.185   Laranja
# 14  15   2025  23/01/2025      Fazenda Sol     101  -22.058,-48.181   Laranja
# 15  16   2025  24/01/2025  Fazenda Estrela     104  -22.062,-48.190   Laranja
# 16   7   2025  25/01/2025      Fazenda Lua     103  -22.060,-48.185   Laranja
# 17  18   2025  26/01/2025      Fazenda Sol     100  -22.058,-48.181   Laranja
# 18  19   2025  27/01/2025  Fazenda Estrela     105  -22.062,-48.190   Laranja
# 19  20   2025         NaN      Fazenda Lua     102  -22.060,-48.185   Laranja
#
#       SinaisPragas  Infestação (%) ResponsavelCampo          dh_ingestao
# 0           Nenhum              30       João Silva  2025-09-07 20:53:45
# 1          Pulgões              55      Maria Souza  2025-09-07 20:53:45
# 2   Mosca-da-fruta              75       João Silva  2025-09-07 20:53:45
# 3           Nenhum             150      Carlos Lima  2025-09-07 20:53:45
# 4          Pulgões               3      Maria Souza  2025-09-07 20:53:45
# 5   Mosca-da-fruta               1       João Silva  2025-09-07 20:53:45
# 6           Nenhum               0      Carlos Lima  2025-09-07 20:53:45
# 7           Nenhum               0      Maria Souza  2025-09-07 20:53:45
# 8           Nenhum               0       João Silva  2025-09-07 20:53:45
# 9   Mosca-da-fruta               0      Carlos Lima  2025-09-07 20:53:45
# 10          Nenhum              13      Maria Souza  2025-09-07 20:53:45
# 11         Pulgões               0       João Silva  2025-09-07 20:53:45
# 12          Nenhum               0      Carlos Lima  2025-09-07 20:53:45
# 13  Mosca-da-fruta              10      Maria Souza  2025-09-07 20:53:45
# 14          Nenhum              20       João Silva  2025-09-07 20:53:45
# 15         Pulgões              50      Carlos Lima  2025-09-07 20:53:45
# 16          Nenhum             110      Maria Souza  2025-09-07 20:53:45
# 17  Mosca-da-fruta              70       João Silva  2025-09-07 20:53:45
# 18         Pulgões               0      Carlos Lima  2025-09-07 20:53:45
# 19          Nenhum               0      Maria Souza  2025-09-07 20:53:45
